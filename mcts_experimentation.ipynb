# %%
# !pip install python-chess
# Out:
# Collecting python-chess
#   Downloading python_chess-1.999-py3-none-any.whl (1.4 kB)
# Collecting chess<2,>=1 (from python-chess)
#   Downloading chess-1.10.0-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 4.9 MB/s eta 0:00:00
# Installing collected packages: chess, python-chess
# Successfully installed chess-1.10.0 python-chess-1.999

# %%
import torch
import chess
import numpy as np
import random
MODEL_PATH = "drive/MyDrive/model_chess_4.pth"  # model_4 is the best one so far
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
NUM_FEATURES = 8 * 8 * 12  # bitmap representation of chessboard is 8 x 8 x num_pieces = 8x8x12
NUM_HIDDEN = 2048  # changed from 2048
CP_MIN = -1000
CP_MAX = 2000

# %%
import torch
import torch.nn as nn

# architecture: 3 layer MLP: input -> 1024 -> 500 -> 50 -> output
# activation: ReLU
# regularization: dropout(0.2) on middle layer
# normalization: batch norm on each layer

class StockwishEvalMLP_Mod(nn.Module):

    def __init__(self, num_features, num_units_hidden, num_classes=1):
        super().__init__()
        self.num_classes = num_classes
        self.num_units_hidden = num_units_hidden

        # the architecture is 3 hidden layers, each with 2048 units
        lin = nn.Linear(num_features, num_units_hidden)
        self.hidden_1 = nn.Sequential(
            lin,
            nn.BatchNorm1d(num_units_hidden),
            nn.ReLU(inplace=True),
            #nn.Dropout(0.2),
        )
        lin = nn.Linear(num_units_hidden, 500)
        self.hidden_2 = nn.Sequential(
            lin,
            nn.BatchNorm1d(500),
            nn.ReLU(inplace=True),
            nn.Dropout(0.2),
        )
        lin = nn.Linear(500, 50)
        self.hidden_3 = nn.Sequential(
            lin,
            nn.BatchNorm1d(50),
            nn.ReLU(inplace=True),
            #nn.Dropout(0.2),
        )

        # added sigmoid hopefully makes the training better
        self.linear_out = nn.Sequential(
            torch.nn.Linear(50, num_classes),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.hidden_1(x)
        x = self.hidden_2(x)
        x = self.hidden_3(x)
        return self.linear_out(x)


# architecture: 3 layer MLP:  input -> 2048 -> 2048 -> 2048 -> output
# activation: ReLU
# regularization: dropout(0.2) on middle layer
# normalization: batch norm on each layer

class StockwishEvalMLP(nn.Module):

    def __init__(self, num_features, num_units_hidden, num_classes=1):
        super().__init__()
        self.num_classes = num_classes
        self.num_units_hidden = num_units_hidden

        # the architecture is 3 hidden layers, each with 2048 units
        lin = nn.Linear(num_features, num_units_hidden)
        self.hidden_1 = nn.Sequential(
            lin,
            nn.BatchNorm1d(num_units_hidden),
            nn.ReLU(inplace=True),
            #nn.Dropout(0.2),
        )
        lin = nn.Linear(num_units_hidden, num_units_hidden)
        self.hidden_2 = nn.Sequential(
            lin,
            nn.BatchNorm1d(num_units_hidden),
            nn.ReLU(inplace=True),
            nn.Dropout(0.2),
        )
        lin = nn.Linear(num_units_hidden, num_units_hidden)
        self.hidden_3 = nn.Sequential(
            lin,
            nn.BatchNorm1d(num_units_hidden),
            nn.ReLU(inplace=True),
            #nn.Dropout(0.2),
        )

        # added sigmoid hopefully makes the training better
        self.linear_out = nn.Sequential(
            torch.nn.Linear(num_units_hidden, num_classes),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.hidden_1(x)
        x = self.hidden_2(x)
        x = self.hidden_3(x)
        return self.linear_out(x)

# %%
#####################
### FROM utils.py ###
#####################

def convert_to_cp(pred, min, max):
    return (pred*max)+min


def bitboards_to_array(bb: np.ndarray) -> np.ndarray:
    bb = np.asarray(bb, dtype=np.uint64)[:, np.newaxis]
    s = 8 * np.arange(7, -1, -1, dtype=np.uint64)
    b = (bb >> s).astype(np.uint8)
    b = np.unpackbits(b, bitorder="little")
    return b.reshape(-1, 8, 8)

def fen_to_vector(fen_string):
    """
    Converts a FEN string to a 768-bit bitboard vector representation.

    Args:
        fen_string: The FEN string representing the chess position.

    Returns:
        A 12 x 8 x 8 numpy array representing the bitboard vector.
    """
    board = chess.Board(fen_string)

    black, white = board.occupied_co

    bitboards = np.array([
        black & board.pawns,
        black & board.knights,
        black & board.bishops,
        black & board.rooks,
        black & board.queens,
        black & board.kings,
        white & board.pawns,
        white & board.knights,
        white & board.bishops,
        white & board.rooks,
        white & board.queens,
        white & board.kings,
        ], dtype=np.uint64)

    # we need to encode the information for which turn it is
    board_array = bitboards_to_array(bitboards).astype('int8')
    if board.turn == chess.WHITE:
        # change all of the arrays of black pieces to -1
        for i in range(6):
            board_array[i] *= -1
    else:
        for i in range(6, 12):
            # change all of the arrays of white pieces to -1
            board_array[i] *= -1

    return array_to_vec(board_array)

def array_to_vec(board_array):
    arr = board_array.reshape(1, 768)
    return arr

# %%
def load_model(path, type=StockwishEvalMLP):

    print(f"Loading model at: {path} ... ")
    if type == StockwishEvalMLP:
        model = StockwishEvalMLP(num_features=NUM_FEATURES, num_units_hidden=NUM_HIDDEN, num_classes=1).to(DEVICE)
    else:
        model = StockwishEvalMLP_Mod(num_features=NUM_FEATURES, num_units_hidden=1024, num_classes=1).to(DEVICE)
    checkpoint = torch.load(path, map_location=torch.device(DEVICE))
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"Model loaded successfully!")
    return model

# %%
class Node:
    def __init__(self, state, parent=None, parent_action=None):
        self.state = state  # FEN
        self.parent = parent #FEN
        self.parent_action = parent_action
        self.children = [] #List of Node of next possible actions

        #self.ucb = 0
        self.N = 0 #Num of times parent node has been visited
        self.n = 0 #Num of times current node has been visited
        self.v = 0 #Exploitation factor: higher v = higher success rate

    def value(self, value_network):
        # value_network should be the trained MLP model which can give a value between (-1, 1) for any given position
        return value_network(self.state)

    def is_leaf(self):
        return len(self.children) == 0

    def outcome(self):
        return chess.Board(self.state).outcome()

    def ucb(self, c=np.sqrt(2)):
       # return self.v + c*np.sqrt(np.log(self.parent.n + 1**(-10))/(self.n + 1**(-10))) # c is the exploration constant, higher = more random moves
        return -self.v/(self.n+1**(-10)) + c*np.sqrt(np.log(self.parent.n + 1**(-10))/(self.n + 1**(-10)))

def selection(curr_node, c=np.sqrt(2)):
    # Select the child node with the highest UCB value
    best_child = curr_node.children[0]
    for child in curr_node.children:
        if child.ucb(c) > best_child.ucb(c):
            #print(child.ucb())
            #print(best_child.ucb())
            best_child = child
    return best_child

def expansion(curr_node):
    # Expand the current node by adding all possible child nodes
    #TODO: this gonna be a lot of possible future moves...
    #TODO: alternating white and black moves (double check)

    board = chess.Board(curr_node.state)
    next_moves = list(board.legal_moves)
    for move in next_moves: #Assuming no next moves if game over TODO: check assumption
        board.push(move)
        new_node = Node(board.fen(), curr_node, move)
        curr_node.children.append(new_node)
        board.pop()


def rollback(curr_node, reward): #reward = 1 if win, 0 if draw, -1 if loss
    #print(chess.Board(curr_node.state))
    #print(f"Current node reward {reward} ^")
    while(curr_node.parent != None):
        curr_node.n += 1
        curr_node.v = curr_node.v+reward if chess.Board(curr_node.state).turn == chess.WHITE else curr_node.v-reward
        curr_node.N += 1
        curr_node = curr_node.parent
    curr_node.n += 1
    curr_node.v += reward
    return curr_node


# this code is from https://github.com/niklasf/python-chess/discussions/864
def material_balance(board):
    white = board.occupied_co[chess.WHITE]
    black = board.occupied_co[chess.BLACK]
    return (
            chess.popcount(white & board.pawns) - chess.popcount(black & board.pawns) +
            3 * (chess.popcount(white & board.knights) - chess.popcount(black & board.knights)) +
            3 * (chess.popcount(white & board.bishops) - chess.popcount(black & board.bishops)) +
            5 * (chess.popcount(white & board.rooks) - chess.popcount(black & board.rooks)) +
            9 * (chess.popcount(white & board.queens) - chess.popcount(black & board.queens))
    )

def decision(probability):
    return random.random() < probability

def get_eval(model, position):
    # position is a FEN string
    model.eval()
    position_vec = fen_to_vector(position)
    position_vec = (torch.tensor(position_vec)).float().to(DEVICE)
    pred = model(position_vec).item()
    return convert_to_cp(pred, CP_MIN, CP_MAX)


def find_next_best_legal_position(model, board, epsilon):
    is_whites_turn = board.turn
    legal_moves = board.legal_moves
    assert legal_moves.count() != 0
    best_move = None
    best_eval = CP_MIN if is_whites_turn else CP_MAX

    #print(legal_moves.count())
    for move in legal_moves:
        board.push(move)
        #display(board)
        position = board.fen()
        #print(board.fen())
        #print(get_eval(model, position))
        current_move_eval = get_eval(model, position)
        #print(current_move_eval)
        #print(move)
        if is_whites_turn:
            if current_move_eval > best_eval:
                best_move = move
                best_eval = current_move_eval
        else:
            if current_move_eval < best_eval:
                best_move = move
                best_eval = current_move_eval
        board.pop()
    # we should push the best_move found by model with probability (1-epsilon) + epsilon/(num_legal_moves)
    prob = (1-epsilon) + epsilon/(legal_moves.count())
    if decision(prob):
        board.push(best_move)
    else:
        move = random.choice(list(legal_moves))
        board.push(move)
    #print(best_eval)

def select_best_move(node, turn):
    list_of_v = [child.v for child in node.children]
    dict_of_v = {child.v: child for child in node.children}
    #return dict_of_v[min(list_of_v)] if turn else dict_of_v[max(list_of_v)]
    return dict_of_v[min(list_of_v)]


def simulate(initial_node, model, max_iterations=100, epsilon=0.8, display_board=False, seed=0):
    """
    initial_position: Node representing our initial position
    model: StockWishMLP class model which predicts value of any position
    max_iterations: how many iterations before we stop forcefully. One iteration = one half-move (e.g. a move for only one player)
    episilon: exploitation/exploration parameter, should be between 0 and 1, the higher the more we prioritize exploration
    display_board: whether we should display the board after each move
    seed: the seed for random() in order to get consistent results

    returns:
      - reward, terminal_node: either -1, 0, 1 and the terminal node

    TODO: new nodes should not be created
    """
    assert 1.0 >= epsilon >= 0
    random.seed(seed)
    current_node = initial_node
    current_position = initial_node.state
    board = chess.Board(current_position)
    # check if terminal
    if board.outcome() is not None:
        if board.outcome().winner is not None:
            return 1 if board.outcome().winner else -1
        else:
            return 0

    iter_index = 0
    while (True):
        iter_index += 1
        find_next_best_legal_position(model, board, epsilon)
        #next_node = Node(next_position, current_node)
        #current_node.children.append(next_node)
        #current_node = next_node
        if display_board:
            #display(board)
            board
        if iter_index >= max_iterations or board.outcome():
            break
    #print(board.outcome())
    #display(board)
    if board.outcome() is None:
        eval = get_eval(model, board.fen())
        mat_balance = material_balance(board)

        # Return value depending only on scaled down material balance
        #return mat_balance/100

        # Return value depending on combination of material balance and eval
        #return 0.7*(mat_balance/20) + 0.3*(eval/1000)

        # Always return (scaled down?) evals
        scale = 0.1
        return scale*float(eval/1000.0)

        # Only return evals if above threshold
        # if abs(eval) > 500:
        #     return float(eval/1000.0)
        # else:
        #     return 0

        # Return discrete values if above threshold
        # if eval > 500:
        #     return 1
        # elif eval < -500:
        #     return -1
        # else:
        #     return 0

    if board.outcome().winner is not None:
        return 1 if board.outcome().winner else -1
    else:
        # we want to avoid draws by repetition or 50 move rule
        if board.outcome().termination == chess.Termination.FIVEFOLD_REPETITION or board.outcome().termination == chess.Termination.FIFTY_MOVES:
            mat_balance = material_balance(board)
            if mat_balance >= 8:
                return 1
            elif mat_balance <= -8:
                return -1
            else:
                return 0
        else:
            return 0


def run_mcts(model, initial_node=Node(chess.STARTING_FEN), num_iterations=10, simulation_depth=50, epsilon=0.8):
    # load model
    if model is None:
        model = load_model(MODEL_PATH, type=StockwishEvalMLP)
    # # create new leaf node
    # root = Node(initial_state)
    # node = root
    # expansion(node)
    # selected_node = selection(node)
    # result, node = simulate(selected_node.state, model)
    # rollback(node)
    # for child in node.children:
    #     pass

    # if node.is_leaf_node():
    #     if node.num_visits == 0:
    #         result = rollout()
    root = initial_node

    for i in range(num_iterations):
        # the selection function selects a node to run the simulation on
        # based on UCT and does expansions when needed
        node = root
        while not node.is_leaf():
            best_child = selection(node)
            node = best_child

        # check if node is a terminal node
        if node.outcome():
            if node.outcome().winner is not None:
                result = 1 if node.outcome().winner else -1
            else:
                result = 0
            #display(chess.Board(node.state))
            print(f"Iteration no. {i} done. Result of simulation: {result}")
            rollback(node, result)
            continue
        # if we reach here it means we have reached a leaf node, simulate
        expansion(node)
        # select best child and simulate
        best_child = selection(node)
        node = best_child
        result = simulate(node, model, max_iterations=simulation_depth, epsilon=epsilon)
        #rollback from selected node using the result
        #print(result)
        rollback(node, result)
        print(f"Iteration no. {i} done. Result of simulation: {result}")
    # for child in root.children:
    #      display(chess.Board(child.state))
    #      print(f"UCB: {child.ucb(c=0)}")
    return select_best_move(root, chess.Board(root.state).turn)

# %%
def play():
    board = chess.Board()
    model = load_model(MODEL_PATH, type=StockwishEvalMLP)
    node = Node(chess.STARTING_FEN)
    print("Welcome to Stockwish!")
    while not board.is_game_over():

        print(board)
        if board.turn == chess.WHITE:
            #move = input("Enter move: ")
            node = run_mcts(model, node, num_iterations=100, simulation_depth=100, epsilon=1.0)
            move = str(node.parent_action)
            board.push_san(move)
        else:
            node = run_mcts(model, node, num_iterations=100, simulation_depth=100, epsilon=1.0)
            board.push_san(str(node.parent_action))
    print(board)
    print("Game over")

play()
# Out:
# Loading model at: drive/MyDrive/model_chess_4.pth ...
# Model loaded successfully!
# Welcome to Stockwish!
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# Iteration no. 0 done. Result of simulation: -0.0018447816371917726
# Iteration no. 1 done. Result of simulation: -0.039241319894790655
# Iteration no. 2 done. Result of simulation: -0.09854035964235663
# Iteration no. 3 done. Result of simulation: 0.042998874187469484
# Iteration no. 4 done. Result of simulation: 0.07270680665969849
# Iteration no. 5 done. Result of simulation: 0.095116126537323
# Iteration no. 6 done. Result of simulation: -0.06194855570793152
# Iteration no. 7 done. Result of simulation: 0.021848809719085694
# Iteration no. 8 done. Result of simulation: -0.01298385262489319
# Iteration no. 9 done. Result of simulation: -0.00016720890998840333
# Iteration no. 10 done. Result of simulation: 0.032980608940124514
# Iteration no. 11 done. Result of simulation: 0.09232861995697023
# Iteration no. 12 done. Result of simulation: -0.015495824813842774
# Iteration no. 13 done. Result of simulation: 0.09232861995697023
# Iteration no. 14 done. Result of simulation: 0.07404227256774902
# Iteration no. 15 done. Result of simulation: 0.09092948436737061
# Iteration no. 16 done. Result of simulation: -0.04702105522155762
# Iteration no. 17 done. Result of simulation: -0.04320657253265381
# Iteration no. 18 done. Result of simulation: -0.03697397112846375
# Iteration no. 19 done. Result of simulation: -1
# Iteration no. 20 done. Result of simulation: 0.0988505244255066
# Iteration no. 21 done. Result of simulation: -0.055501440167427064
# Iteration no. 22 done. Result of simulation: -0.04606981277465821
# Iteration no. 23 done. Result of simulation: 0.09016280174255371
# Iteration no. 24 done. Result of simulation: -0.013040012121200562
# Iteration no. 25 done. Result of simulation: -0.0869458705186844
# Iteration no. 26 done. Result of simulation: -0.0397517204284668
# Iteration no. 27 done. Result of simulation: 0.0506176233291626
# Iteration no. 28 done. Result of simulation: -0.055965274572372437
# Iteration no. 29 done. Result of simulation: 0.0915865182876587
# Iteration no. 30 done. Result of simulation: -0.03507617712020874
# Iteration no. 31 done. Result of simulation: -0.004451805353164673
# Iteration no. 32 done. Result of simulation: -0.09609760642051697
# Iteration no. 33 done. Result of simulation: -0.03947298526763916
# Iteration no. 34 done. Result of simulation: 0.05924723148345948
# Iteration no. 35 done. Result of simulation: -1
# Iteration no. 36 done. Result of simulation: 0.04603581428527832
# Iteration no. 37 done. Result of simulation: -0.04829337000846863
# Iteration no. 38 done. Result of simulation: 0.09882540702819825
# Iteration no. 39 done. Result of simulation: 0.05834898948669434
# Iteration no. 40 done. Result of simulation: -0.011958223581314088
# Iteration no. 41 done. Result of simulation: 0.04525545835494996
# Iteration no. 42 done. Result of simulation: 0.08487226963043214
# Iteration no. 43 done. Result of simulation: -0.09949254184029997
# Iteration no. 44 done. Result of simulation: -0.042513263225555424
# Iteration no. 45 done. Result of simulation: 0.0808996081352234
# Iteration no. 46 done. Result of simulation: -0.05895684063434601
# Iteration no. 47 done. Result of simulation: -0.047364902496337895
# Iteration no. 48 done. Result of simulation: 0.009912312030792236
# Iteration no. 49 done. Result of simulation: -0.03051809072494507
# Iteration no. 50 done. Result of simulation: 0.025030243396759036
# Iteration no. 51 done. Result of simulation: 0.04889092445373536
# Iteration no. 52 done. Result of simulation: 0.01826852560043335
# Iteration no. 53 done. Result of simulation: 0.05924723148345948
# Iteration no. 54 done. Result of simulation: -0.014856243133544923
# Iteration no. 55 done. Result of simulation: 1
# Iteration no. 56 done. Result of simulation: -0.05343582928180695
# Iteration no. 57 done. Result of simulation: 0.08472373485565186
# Iteration no. 58 done. Result of simulation: 0.04846562147140503
# Iteration no. 59 done. Result of simulation: -0.04785934090614319
# Iteration no. 60 done. Result of simulation: 0.01152559518814087
# Iteration no. 61 done. Result of simulation: -0.01000933051109314
# Iteration no. 62 done. Result of simulation: 0.09330192804336548
# Iteration no. 63 done. Result of simulation: -1
# Iteration no. 64 done. Result of simulation: 1
# Iteration no. 65 done. Result of simulation: -0.008263176679611206
# Iteration no. 66 done. Result of simulation: 0.010051679611206055
# Iteration no. 67 done. Result of simulation: -0.05895684063434601
# Iteration no. 68 done. Result of simulation: -0.09021913707256318
# Iteration no. 69 done. Result of simulation: -0.09467836730182172
# Iteration no. 70 done. Result of simulation: 0.046248364448547366
# Iteration no. 71 done. Result of simulation: -0.033577293157577515
# Iteration no. 72 done. Result of simulation: 0.0027904272079467777
# Iteration no. 73 done. Result of simulation: 0.02940635681152344
# Iteration no. 74 done. Result of simulation: 0.04587222337722779
# Iteration no. 75 done. Result of simulation: 0.021072041988372803
# Iteration no. 76 done. Result of simulation: 0.02855978012084961
# Iteration no. 77 done. Result of simulation: 0.04188206195831299
# Iteration no. 78 done. Result of simulation: 0.04423837661743164
# Iteration no. 79 done. Result of simulation: 0.0665366291999817
# Iteration no. 80 done. Result of simulation: 0.060237455368041995
# Iteration no. 81 done. Result of simulation: 0.004311513900756836
# Iteration no. 82 done. Result of simulation: 0.0029858946800231934
# Iteration no. 83 done. Result of simulation: 0.09501868486404419
# Iteration no. 84 done. Result of simulation: 0.05493067502975464
# Iteration no. 85 done. Result of simulation: -0.004911267757415772
# Iteration no. 86 done. Result of simulation: 0.035547292232513426
# Iteration no. 87 done. Result of simulation: -0.06027766168117524
# Iteration no. 88 done. Result of simulation: 0.03548164367675782
# Iteration no. 89 done. Result of simulation: -0.08182156682014466
# Iteration no. 90 done. Result of simulation: 0.011145782470703126
# Iteration no. 91 done. Result of simulation: 0.06518874168395997
# Iteration no. 92 done. Result of simulation: 0.021072041988372803
# Iteration no. 93 done. Result of simulation: 0.03508614301681519
# Iteration no. 94 done. Result of simulation: 0.04338185787200928
# Iteration no. 95 done. Result of simulation: 0.06720058917999268
# Iteration no. 96 done. Result of simulation: 0.03606783151626587
# Iteration no. 97 done. Result of simulation: -0.09199546277523041
# Iteration no. 98 done. Result of simulation: -0.011926001310348511
# Iteration no. 99 done. Result of simulation: -0.0003586232662200928
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . P . .
# P P P P P . P P
# R N B Q K B N R
# Iteration no. 0 done. Result of simulation: 0.040964519977569586
# Iteration no. 1 done. Result of simulation: -0.01974373459815979
# Iteration no. 2 done. Result of simulation: -0.00747976303100586
# Iteration no. 3 done. Result of simulation: -0.08173066526651383
# Iteration no. 4 done. Result of simulation: -0.02314937114715576
# Iteration no. 5 done. Result of simulation: -0.038709402084350586
# Iteration no. 6 done. Result of simulation: -0.0005845844745635987
# Iteration no. 7 done. Result of simulation: -0.03474467992782593
# Iteration no. 8 done. Result of simulation: -0.0596752941608429
# Iteration no. 9 done. Result of simulation: 0.09956070184707642
# Iteration no. 10 done. Result of simulation: 0.04090995788574219
# Iteration no. 11 done. Result of simulation: 0.048870122432708746
# Iteration no. 12 done. Result of simulation: -0.07378093898296356
# Iteration no. 13 done. Result of simulation: -0.03162341117858887
# Iteration no. 14 done. Result of simulation: 0.019747996330261232
# Iteration no. 15 done. Result of simulation: 0.08883157968521119
# Iteration no. 16 done. Result of simulation: -0.08731960356235505
# Iteration no. 17 done. Result of simulation: 0.0006702780723571778
# Iteration no. 18 done. Result of simulation: 0.0479179859161377
# Iteration no. 19 done. Result of simulation: 0.09677404165267944
# Iteration no. 20 done. Result of simulation: -0.058948507905006414
# Iteration no. 21 done. Result of simulation: 0.02941170930862427
# Iteration no. 22 done. Result of simulation: 0.056339180469512945
# Iteration no. 23 done. Result of simulation: -0.016724365949630737
# Iteration no. 24 done. Result of simulation: 0.09589289426803589
# Iteration no. 25 done. Result of simulation: 0.047842669486999514
# Iteration no. 26 done. Result of simulation: -0.01440795660018921
# Iteration no. 27 done. Result of simulation: 1
# Iteration no. 28 done. Result of simulation: -1
# Iteration no. 29 done. Result of simulation: -0.07227365970611573
# Iteration no. 30 done. Result of simulation: -0.029231733083724978
# Iteration no. 31 done. Result of simulation: -0.0759772002696991
# Iteration no. 32 done. Result of simulation: 0.05314949750900269
# Iteration no. 33 done. Result of simulation: -0.08792226389050484
# Iteration no. 34 done. Result of simulation: -0.09733651224523783
# Iteration no. 35 done. Result of simulation: -1
# Iteration no. 36 done. Result of simulation: 0.02373992204666138
# Iteration no. 37 done. Result of simulation: -0.008679193258285523
# Iteration no. 38 done. Result of simulation: 0.0151625394821167
# Iteration no. 39 done. Result of simulation: -0.0037899732589721682
# Iteration no. 40 done. Result of simulation: -0.007458412647247315
# Iteration no. 41 done. Result of simulation: -0.015669244527816772
# Iteration no. 42 done. Result of simulation: -0.0657892018556595
# Iteration no. 43 done. Result of simulation: 0.02004605531692505
# Iteration no. 44 done. Result of simulation: 0.046307706832885744
# Iteration no. 45 done. Result of simulation: 0.023838436603546145
# Iteration no. 46 done. Result of simulation: -0.04327689409255982
# Iteration no. 47 done. Result of simulation: -0.005189096927642823
# Iteration no. 48 done. Result of simulation: -0.04411365389823914
# Iteration no. 49 done. Result of simulation: -0.03194845914840699
# Iteration no. 50 done. Result of simulation: -0.03243898153305054
# Iteration no. 51 done. Result of simulation: 0.09584838151931763
# Iteration no. 52 done. Result of simulation: 0.001523447036743164
# Iteration no. 53 done. Result of simulation: 0.07217204570770264
# Iteration no. 54 done. Result of simulation: 0.010111665725708008
# Iteration no. 55 done. Result of simulation: -0.03196476697921753
# Iteration no. 56 done. Result of simulation: 0.09967489242553712
# Iteration no. 57 done. Result of simulation: -0.015943586826324463
# Iteration no. 58 done. Result of simulation: 0.09705554246902466
# Iteration no. 59 done. Result of simulation: 0.015874481201171877
# Iteration no. 60 done. Result of simulation: 0.021995019912719727
# Iteration no. 61 done. Result of simulation: -0.09960984205827117
# Iteration no. 62 done. Result of simulation: 0.03773789405822754
# Iteration no. 63 done. Result of simulation: -0.0016524434089660645
# Iteration no. 64 done. Result of simulation: 0.09375509023666383
# Iteration no. 65 done. Result of simulation: -0.09470302909612656
# Iteration no. 66 done. Result of simulation: 0.08526356220245362
# Iteration no. 67 done. Result of simulation: 0.010851776599884034
# Iteration no. 68 done. Result of simulation: 0.04623657464981079
# Iteration no. 69 done. Result of simulation: 0.06385987997055054
# Iteration no. 70 done. Result of simulation: -0.00863032341003418
# Iteration no. 71 done. Result of simulation: -0.05560206174850464
# Iteration no. 72 done. Result of simulation: 0.0010087132453918458
# Iteration no. 73 done. Result of simulation: 0.0019966840744018556
# Iteration no. 74 done. Result of simulation: -0.018907624483108523
# Iteration no. 75 done. Result of simulation: 0.022227394580841067
# Iteration no. 76 done. Result of simulation: -0.024458152055740357
# Iteration no. 77 done. Result of simulation: 0.02248862981796265
# Iteration no. 78 done. Result of simulation: 0.007188844680786133
# Iteration no. 79 done. Result of simulation: 0.07407647371292114
# Iteration no. 80 done. Result of simulation: 0.002557837963104248
# Iteration no. 81 done. Result of simulation: 0.09836884737014771
# Iteration no. 82 done. Result of simulation: -0.06356818079948426
# Iteration no. 83 done. Result of simulation: 0.05345367193222046
# Iteration no. 84 done. Result of simulation: 0.09890258312225342
# Iteration no. 85 done. Result of simulation: -0.0962697558104992
# Iteration no. 86 done. Result of simulation: 0.056145024299621586
# Iteration no. 87 done. Result of simulation: -0.09993236892041751
# Iteration no. 88 done. Result of simulation: 0.06508913040161134
# Iteration no. 89 done. Result of simulation: 0.01671844720840454
# Iteration no. 90 done. Result of simulation: 0.06871680021286011
# Iteration no. 91 done. Result of simulation: 0.00806654691696167
# Iteration no. 92 done. Result of simulation: 0.03161081075668335
# Iteration no. 93 done. Result of simulation: 0.034146356582641604
# Iteration no. 94 done. Result of simulation: 0.08204429149627686
# Iteration no. 95 done. Result of simulation: 0.008673524856567383
# Iteration no. 96 done. Result of simulation: 0.07496066093444824
# Iteration no. 97 done. Result of simulation: -0.07160266041755677
# Iteration no. 98 done. Result of simulation: -0.021764278411865234
# Iteration no. 99 done. Result of simulation: 0.06266976594924926
# r n b q k b n r
# p p p p p . p p
# . . . . . p . .
# . . . . . . . .
# . . . . . . . .
# . . . . . P . .
# P P P P P . P P
# R N B Q K B N R
# Iteration no. 0 done. Result of simulation: 0.012788629531860352
# Iteration no. 1 done. Result of simulation: 0.05651402473449707
# Iteration no. 2 done. Result of simulation: 0.028912854194641114
# Iteration no. 3 done. Result of simulation: -0.06219454407691956
# Iteration no. 4 done. Result of simulation: 0.07306158542633057
# Iteration no. 5 done. Result of simulation: 0.017764365673065188
# Iteration no. 6 done. Result of simulation: 0.07306158542633057
# Iteration no. 7 done. Result of simulation: 0.09116021394729615
# Iteration no. 8 done. Result of simulation: -0.0627176433801651
# Iteration no. 9 done. Result of simulation: 0.03376902341842652
# Iteration no. 10 done. Result of simulation: 0.07341145277023316
# Iteration no. 11 done. Result of simulation: -0.05512811243534088
# Iteration no. 12 done. Result of simulation: -0.04512624740600586
# Iteration no. 13 done. Result of simulation: -0.03307352662086487
# Iteration no. 14 done. Result of simulation: 0.07745230197906494
# Iteration no. 15 done. Result of simulation: 0.06426393985748291
# Iteration no. 16 done. Result of simulation: -0.0959551464766264
# Iteration no. 17 done. Result of simulation: 0.08664027452468873
# Iteration no. 18 done. Result of simulation: 0.09537115097045899
# Iteration no. 19 done. Result of simulation: -0.02567124366760254
# Iteration no. 20 done. Result of simulation: -0.01325281858444214
# Iteration no. 21 done. Result of simulation: 0.03679119348526001
# Iteration no. 22 done. Result of simulation: 0.07947009801864624
# Iteration no. 23 done. Result of simulation: 0.03592175245285034
# Iteration no. 24 done. Result of simulation: 0.05361450910568238
# Iteration no. 25 done. Result of simulation: 0.09189053773880006
# Iteration no. 26 done. Result of simulation: 0.018893682956695558
# Iteration no. 27 done. Result of simulation: -0.024130511283874514
# Iteration no. 28 done. Result of simulation: -0.09993309575947934
# Iteration no. 29 done. Result of simulation: -0.09701954070478679
# Iteration no. 30 done. Result of simulation: 0.09634507894515992
# Iteration no. 31 done. Result of simulation: 0.006564974784851074
# Iteration no. 32 done. Result of simulation: -0.038007378578186035
# Iteration no. 33 done. Result of simulation: -0.019617921113967898
# Iteration no. 34 done. Result of simulation: -0.03210440278053284
# Iteration no. 35 done. Result of simulation: -0.014335954189300538
# Iteration no. 36 done. Result of simulation: -0.06329564452171325
# Iteration no. 37 done. Result of simulation: -0.012061595916748047
# Iteration no. 38 done. Result of simulation: 0.045852625370025636
# Iteration no. 39 done. Result of simulation: -0.023310482501983643
# Iteration no. 40 done. Result of simulation: 0.02600716352462769
# Iteration no. 41 done. Result of simulation: -0.07540823817253113
# Iteration no. 42 done. Result of simulation: 0.0734373927116394
# Iteration no. 43 done. Result of simulation: 0.05412095785140991
# Iteration no. 44 done. Result of simulation: 0.012740206718444825
# Iteration no. 45 done. Result of simulation: -0.03335187435150146
# Iteration no. 46 done. Result of simulation: 0.021793603897094727
# Iteration no. 47 done. Result of simulation: -0.09978795244824142
# Iteration no. 48 done. Result of simulation: 0.04884288311004639
# Iteration no. 49 done. Result of simulation: -0.004758560657501221
# Iteration no. 50 done. Result of simulation: -0.022047513723373414
# Iteration no. 51 done. Result of simulation: 0.008603739738464357
# Iteration no. 52 done. Result of simulation: -0.07826624512672425
# Iteration no. 53 done. Result of simulation: -0.04641251564025879
# Iteration no. 54 done. Result of simulation: -0.0015699326992034913
# Iteration no. 55 done. Result of simulation: -0.0272666871547699
# Iteration no. 56 done. Result of simulation: -0.0402147650718689
# Iteration no. 57 done. Result of simulation: 0.040162968635559085
# Iteration no. 58 done. Result of simulation: 0.05703595876693726
# Iteration no. 59 done. Result of simulation: -0.03862749934196472
# Iteration no. 60 done. Result of simulation: 0.09956628084182739
# Iteration no. 61 done. Result of simulation: 0.01777820587158203
# Iteration no. 62 done. Result of simulation: 0.011354410648345949
# Iteration no. 63 done. Result of simulation: -0.03052167892456055
# Iteration no. 64 done. Result of simulation: 0.09890265464782716
# Iteration no. 65 done. Result of simulation: -0.024467217922210696
# Iteration no. 66 done. Result of simulation: 0.0331463098526001
# Iteration no. 67 done. Result of simulation: -0.039481669664382935
# Iteration no. 68 done. Result of simulation: -0.05876978635787964
# Iteration no. 69 done. Result of simulation: -0.054437038302421574
# Iteration no. 70 done. Result of simulation: -0.05559636950492859
# Iteration no. 71 done. Result of simulation: -0.029776787757873537
# Iteration no. 72 done. Result of simulation: -0.002843326330184937
# Iteration no. 73 done. Result of simulation: 0.014663159847259521
# Iteration no. 74 done. Result of simulation: 0.0011527299880981447
# Iteration no. 75 done. Result of simulation: -0.003508681058883667
# Iteration no. 76 done. Result of simulation: -0.07100729644298553
# Iteration no. 77 done. Result of simulation: 0.08771916627883912
# Iteration no. 78 done. Result of simulation: -0.03983289599418641
# Iteration no. 79 done. Result of simulation: 0.002872300148010254
# Iteration no. 80 done. Result of simulation: -0.07913138568401337
# Iteration no. 81 done. Result of simulation: -0.018876689672470096
# Iteration no. 82 done. Result of simulation: 0.07414250373840332
# Iteration no. 83 done. Result of simulation: -0.003742039203643799
# Iteration no. 84 done. Result of simulation: 0.010284626483917238
# Iteration no. 85 done. Result of simulation: 0.03774049282073975
# Iteration no. 86 done. Result of simulation: 0.0744099259376526
# Iteration no. 87 done. Result of simulation: -1
# Iteration no. 88 done. Result of simulation: 0.048821902275085455
# Iteration no. 89 done. Result of simulation: -0.00871078372001648
# Iteration no. 90 done. Result of simulation: -0.07865927666425705
# Iteration no. 91 done. Result of simulation: -0.0870697557926178
# Iteration no. 92 done. Result of simulation: 0.08151957988739014
# Iteration no. 93 done. Result of simulation: -0.019007337093353272
# Iteration no. 94 done. Result of simulation: -0.04719967842102051
# Iteration no. 95 done. Result of simulation: -0.04158211946487427
# Iteration no. 96 done. Result of simulation: -0.04907652735710144
# Iteration no. 97 done. Result of simulation: 0.058473944664001465
# Iteration no. 98 done. Result of simulation: 0.06590930223464966
# Iteration no. 99 done. Result of simulation: -0.029821717739105226
# r n b q k b n r
# p p p p p . p p
# . . . . . p . .
# . . . . . . . .
# . . . . . . . .
# . . . . . P . N
# P P P P P . P P
# R N B Q K B . R
# Iteration no. 0 done. Result of simulation: 0.036109650135040285
# Iteration no. 1 done. Result of simulation: -1
# Iteration no. 2 done. Result of simulation: -1
# Iteration no. 3 done. Result of simulation: -0.026173508167266848
# Iteration no. 4 done. Result of simulation: -0.05246951282024384
# Iteration no. 5 done. Result of simulation: -0.038887643814086915
# Iteration no. 6 done. Result of simulation: 0.09955004453659058
# Iteration no. 7 done. Result of simulation: 0.003161334991455078
# Iteration no. 8 done. Result of simulation: 0.025754332542419434
# Iteration no. 9 done. Result of simulation: -0.011854332685470582
# Iteration no. 10 done. Result of simulation: 0.025642478466033937
# Iteration no. 11 done. Result of simulation: 0.014078211784362794
# Iteration no. 12 done. Result of simulation: 0.022034454345703128
# Iteration no. 13 done. Result of simulation: 0.09101469516754152
# Iteration no. 14 done. Result of simulation: -0.07345381975173951
# Iteration no. 15 done. Result of simulation: -0.08686949163675309
# Iteration no. 16 done. Result of simulation: 0.02244023084640503
# Iteration no. 17 done. Result of simulation: 0.028020846843719485
# Iteration no. 18 done. Result of simulation: 0.08651725053787232
# Iteration no. 19 done. Result of simulation: 0.09670695066452027
# Iteration no. 20 done. Result of simulation: 0.09316474199295044
# Iteration no. 21 done. Result of simulation: 0.015906262397766113
# Iteration no. 22 done. Result of simulation: 1
# Iteration no. 23 done. Result of simulation: 0.07385864257812501
# Iteration no. 24 done. Result of simulation: -0.04907734394073487
# Iteration no. 25 done. Result of simulation: 0.0024666428565979005
# Iteration no. 26 done. Result of simulation: 0.008130836486816407
# Iteration no. 27 done. Result of simulation: 0.08807412385940552
# Iteration no. 28 done. Result of simulation: 0.0799305558204651
# Iteration no. 29 done. Result of simulation: 0.07539280652999879
# Iteration no. 30 done. Result of simulation: 0.013932979106903077
# Iteration no. 31 done. Result of simulation: -0.03465184569358826
# Iteration no. 32 done. Result of simulation: -1
# Iteration no. 33 done. Result of simulation: 0.00634150505065918
# Iteration no. 34 done. Result of simulation: 0.09530549049377442
# Iteration no. 35 done. Result of simulation: 0.06704267263412476
# Iteration no. 36 done. Result of simulation: -0.09999793060032972
# Iteration no. 37 done. Result of simulation: 0.006377065181732178
# Iteration no. 38 done. Result of simulation: -0.010627824068069459
# Iteration no. 39 done. Result of simulation: 1
# Iteration no. 40 done. Result of simulation: 0.015235435962677003
# Iteration no. 41 done. Result of simulation: -0.01838911771774292
# Iteration no. 42 done. Result of simulation: 0.051574897766113285
# Iteration no. 43 done. Result of simulation: -0.031952834129333495
# Iteration no. 44 done. Result of simulation: -0.07442049980163574
# Iteration no. 45 done. Result of simulation: 0.023488748073577884
# Iteration no. 46 done. Result of simulation: 0.031250524520874026
# Iteration no. 47 done. Result of simulation: -0.06357933878898621
# Iteration no. 48 done. Result of simulation: 0.029661059379577637
# Iteration no. 49 done. Result of simulation: -0.09173146858811379
# Iteration no. 50 done. Result of simulation: 0.056011652946472174
# Iteration no. 51 done. Result of simulation: -0.09570718705654145
# Iteration no. 52 done. Result of simulation: -0.06827628910541535
# Iteration no. 53 done. Result of simulation: -0.0903764232993126
# Iteration no. 54 done. Result of simulation: -1
# Iteration no. 55 done. Result of simulation: 1
# Iteration no. 56 done. Result of simulation: 0.07042156457901001
# Iteration no. 57 done. Result of simulation: -0.006411653757095338
# Iteration no. 58 done. Result of simulation: 0.09842560291290284
# Iteration no. 59 done. Result of simulation: -0.02220761775970459
# Iteration no. 60 done. Result of simulation: -0.0034300565719604494
# Iteration no. 61 done. Result of simulation: 1
# Iteration no. 62 done. Result of simulation: -0.0003109753131866455
# Iteration no. 63 done. Result of simulation: 0.034398245811462405
# Iteration no. 64 done. Result of simulation: -0.08076882958412171
# Iteration no. 65 done. Result of simulation: -0.04805811643600464
# Iteration no. 66 done. Result of simulation: -0.08484556525945663
# Iteration no. 67 done. Result of simulation: -0.005088871717453003
# Iteration no. 68 done. Result of simulation: -0.010524338483810425
# Iteration no. 69 done. Result of simulation: 1
# Iteration no. 70 done. Result of simulation: -0.0033976376056671143
# Iteration no. 71 done. Result of simulation: 0.09008674621582032
# Iteration no. 72 done. Result of simulation: -0.028031098842620852
# Iteration no. 73 done. Result of simulation: 0.01668442487716675
# Iteration no. 74 done. Result of simulation: 0.09957083463668824
# Iteration no. 75 done. Result of simulation: -0.025095212459564212
# Iteration no. 76 done. Result of simulation: -0.03563452363014221
# Iteration no. 77 done. Result of simulation: 0.017548787593841552
# Iteration no. 78 done. Result of simulation: 0.07670911550521851
# Iteration no. 79 done. Result of simulation: -0.009927827119827272
# Iteration no. 80 done. Result of simulation: -0.00950048565864563
# Iteration no. 81 done. Result of simulation: 0.006178057193756104
# Iteration no. 82 done. Result of simulation: -0.09996600358572323
# Iteration no. 83 done. Result of simulation: -0.003211575746536255
# Iteration no. 84 done. Result of simulation: -0.01233806610107422
# Iteration no. 85 done. Result of simulation: -0.0021457672119140625
# Iteration no. 86 done. Result of simulation: -0.02273332476615906
# Iteration no. 87 done. Result of simulation: 0.0006898522377014161
# Iteration no. 88 done. Result of simulation: -0.00031910538673400883
# Iteration no. 89 done. Result of simulation: 0.08235819339752198
# Iteration no. 90 done. Result of simulation: -0.04048043489456177
# Iteration no. 91 done. Result of simulation: 0.021794211864471436
# Iteration no. 92 done. Result of simulation: -0.005527716875076295
# Iteration no. 93 done. Result of simulation: 0.025605738162994385
# Iteration no. 94 done. Result of simulation: -0.015462124347686769
# Iteration no. 95 done. Result of simulation: 0.05798095464706421
# Iteration no. 96 done. Result of simulation: -0.024064254760742188
# Iteration no. 97 done. Result of simulation: -0.06675496697425842
# Iteration no. 98 done. Result of simulation: -0.022552084922790528
# Iteration no. 99 done. Result of simulation: -0.060711911320686346
# r n b q k b n r
# p p p . p . p p
# . . . p . p . .
# . . . . . . . .
# . . . . . . . .
# . . . . . P . N
# P P P P P . P P
# R N B Q K B . R
# Iteration no. 0 done. Result of simulation: -0.027098923921585083
# Iteration no. 1 done. Result of simulation: 0.0916027307510376
# Iteration no. 2 done. Result of simulation: 0.036531925201416016
# Iteration no. 3 done. Result of simulation: 0.06253178119659424
# Iteration no. 4 done. Result of simulation: 0.03446178436279297
# Iteration no. 5 done. Result of simulation: -0.034596437215805055
# Iteration no. 6 done. Result of simulation: -0.03318117260932923
# Iteration no. 7 done. Result of simulation: 0.009805703163146974
# Iteration no. 8 done. Result of simulation: -0.002539604902267456
# Iteration no. 9 done. Result of simulation: 0.006121599674224854
# Iteration no. 10 done. Result of simulation: 0.07684149742126466
# Iteration no. 11 done. Result of simulation: 0.043373084068298345
# Iteration no. 12 done. Result of simulation: -0.05216993093490601
# Iteration no. 13 done. Result of simulation: -0.09966060211881995
# Iteration no. 14 done. Result of simulation: -0.0090537428855896
# Iteration no. 15 done. Result of simulation: -0.08842452317476274
# Iteration no. 16 done. Result of simulation: 0.006946372985839844
# Iteration no. 17 done. Result of simulation: -0.07657088339328766
# Iteration no. 18 done. Result of simulation: 0.04001879692077637
# Iteration no. 19 done. Result of simulation: 0.09053914546966553
# Iteration no. 20 done. Result of simulation: 1
# Iteration no. 21 done. Result of simulation: 0.0996778964996338
# Iteration no. 22 done. Result of simulation: -0.016187822818756106
# Iteration no. 23 done. Result of simulation: 0.06935310363769531
# Iteration no. 24 done. Result of simulation: 0.09188920259475708
# Iteration no. 25 done. Result of simulation: -0.03434332609176636
# Iteration no. 26 done. Result of simulation: -0.004058307409286499
# Iteration no. 27 done. Result of simulation: -0.059753748774528506
# Iteration no. 28 done. Result of simulation: -1
# Iteration no. 29 done. Result of simulation: 1
# Iteration no. 30 done. Result of simulation: -0.032473063468933104
# Iteration no. 31 done. Result of simulation: -0.029544126987457276
# Iteration no. 32 done. Result of simulation: 0.07074604034423829
# Iteration no. 33 done. Result of simulation: 0.05041418075561524
# Iteration no. 34 done. Result of simulation: -0.0041539669036865234
# Iteration no. 35 done. Result of simulation: 0.08021081686019899
# Iteration no. 36 done. Result of simulation: 0.029336166381835938
# Iteration no. 37 done. Result of simulation: 0.04731600284576416
# Iteration no. 38 done. Result of simulation: -0.03582214713096619
# Iteration no. 39 done. Result of simulation: -1
# Iteration no. 40 done. Result of simulation: -0.002815550565719605
# Iteration no. 41 done. Result of simulation: 0.05148216485977173
# Iteration no. 42 done. Result of simulation: 0.02330096960067749
# Iteration no. 43 done. Result of simulation: -0.044194817543029785
# Iteration no. 44 done. Result of simulation: 0.030339837074279785
# Iteration no. 45 done. Result of simulation: 0.09172035455703736
# Iteration no. 46 done. Result of simulation: -0.09802626557648182
# Iteration no. 47 done. Result of simulation: 0.01568424701690674
# Iteration no. 48 done. Result of simulation: -0.08639865070581437
# Iteration no. 49 done. Result of simulation: 0.06306960582733155
# Iteration no. 50 done. Result of simulation: -0.029043197631835938
# Iteration no. 51 done. Result of simulation: -0.09716128930449486
# Iteration no. 52 done. Result of simulation: 0.0172521710395813
# Iteration no. 53 done. Result of simulation: -0.039972782135009766
# Iteration no. 54 done. Result of simulation: 0.09864485263824463
# Iteration no. 55 done. Result of simulation: -0.04316346049308777
# Iteration no. 56 done. Result of simulation: -0.01888927221298218
# Iteration no. 57 done. Result of simulation: 0.031524944305419925
# Iteration no. 58 done. Result of simulation: -0.019455039501190187
# Iteration no. 59 done. Result of simulation: 0.05950905084609986
# Iteration no. 60 done. Result of simulation: 1
# Iteration no. 61 done. Result of simulation: 0.0035643815994262696
# Iteration no. 62 done. Result of simulation: 0.020293259620666505
# Iteration no. 63 done. Result of simulation: -0.05249417126178742
# Iteration no. 64 done. Result of simulation: -0.04216755032539368
# Iteration no. 65 done. Result of simulation: -0.015480113029479981
# Iteration no. 66 done. Result of simulation: 0.026373362541198733
# Iteration no. 67 done. Result of simulation: 0.09998271465301514
# Iteration no. 68 done. Result of simulation: -0.04459203481674195
# Iteration no. 69 done. Result of simulation: 0.02500354051589966
# Iteration no. 70 done. Result of simulation: 0.06469318866729737
# Iteration no. 71 done. Result of simulation: -0.09367652237415314
# Iteration no. 72 done. Result of simulation: 0.046232438087463384
# Iteration no. 73 done. Result of simulation: 0.0979878306388855
# Iteration no. 74 done. Result of simulation: 0.06763246059417725
# Iteration no. 75 done. Result of simulation: 0.0012508630752563477
# Iteration no. 76 done. Result of simulation: 0.026196229457855227
# Iteration no. 77 done. Result of simulation: -0.03228382468223572
# Iteration no. 78 done. Result of simulation: -0.005023956298828125
# Iteration no. 79 done. Result of simulation: -0.059753748774528506
# Iteration no. 80 done. Result of simulation: 0.060253489017486575
# Iteration no. 81 done. Result of simulation: 0.03065999746322632
# Iteration no. 82 done. Result of simulation: 0.04760570526123047
# Iteration no. 83 done. Result of simulation: -0.06652821898460388
# Iteration no. 84 done. Result of simulation: -0.02242600917816162
# Iteration no. 85 done. Result of simulation: 0.09823955297470094
# Iteration no. 86 done. Result of simulation: -0.052606371045112614
# Iteration no. 87 done. Result of simulation: 0.07774829864501953
# Iteration no. 88 done. Result of simulation: 0.004417920112609864
# Iteration no. 89 done. Result of simulation: 0.04168161153793335
# Iteration no. 90 done. Result of simulation: -0.08579700440168381
# Iteration no. 91 done. Result of simulation: -0.04315805435180664
# Iteration no. 92 done. Result of simulation: 0.09984841346740723
# Iteration no. 93 done. Result of simulation: -0.0423586905002594
# Iteration no. 94 done. Result of simulation: 0.09880288839340211
# Iteration no. 95 done. Result of simulation: -0.00043920874595642094
# Iteration no. 96 done. Result of simulation: 0.019209420680999758
# Iteration no. 97 done. Result of simulation: 0.06766602993011475
# Iteration no. 98 done. Result of simulation: 0.09459192752838136
# Iteration no. 99 done. Result of simulation: -0.08654471188783647
# r n b q k b n r
# p p p . p . p p
# . . . p . p . .
# . . . . . . . .
# . . . . . . . .
# . . P . . P . N
# P P . P P . P P
# R N B Q K B . R
# Iteration no. 0 done. Result of simulation: -0.008120483160018921
# Iteration no. 1 done. Result of simulation: -0.08853327333927155
# Iteration no. 2 done. Result of simulation: -0.015487277507781984
# Iteration no. 3 done. Result of simulation: 0.005587399005889893
# Iteration no. 4 done. Result of simulation: -0.062065550684928895
# Iteration no. 5 done. Result of simulation: -0.0962787065654993
# Iteration no. 6 done. Result of simulation: 0.05072143077850342
# Iteration no. 7 done. Result of simulation: -0.07678399085998536
# Iteration no. 8 done. Result of simulation: 0.013225221633911134
# Iteration no. 9 done. Result of simulation: -0.06613775789737701
# Iteration no. 10 done. Result of simulation: 0.04605015516281128
# Iteration no. 11 done. Result of simulation: 0.038021743297576904
# Iteration no. 12 done. Result of simulation: -0.0004152834415435791
# Iteration no. 13 done. Result of simulation: -0.020198512077331546
# Iteration no. 14 done. Result of simulation: 0.047418200969696046
# Iteration no. 15 done. Result of simulation: -0.024652355909347536
# Iteration no. 16 done. Result of simulation: -0.038382822275161745
# Iteration no. 17 done. Result of simulation: 0.020366787910461426
# Iteration no. 18 done. Result of simulation: -0.05104477405548096
# Iteration no. 19 done. Result of simulation: -0.021352827548980713
# Iteration no. 20 done. Result of simulation: -0.09543949700891972
# Iteration no. 21 done. Result of simulation: -0.03556985259056091
# Iteration no. 22 done. Result of simulation: 0.025186872482299807
# Iteration no. 23 done. Result of simulation: -0.004845744371414185
# Iteration no. 24 done. Result of simulation: -0.03129275441169739
# Iteration no. 25 done. Result of simulation: 0.09924516677856446
# Iteration no. 26 done. Result of simulation: 0.0005440235137939454
# Iteration no. 27 done. Result of simulation: -0.046179312467575076
# Iteration no. 28 done. Result of simulation: 0.007920312881469728
# Iteration no. 29 done. Result of simulation: 0.016914141178131104
# Iteration no. 30 done. Result of simulation: -0.04920991063117981
# Iteration no. 31 done. Result of simulation: 0.0007591962814331055
# Iteration no. 32 done. Result of simulation: 0.015509033203125001
# Iteration no. 33 done. Result of simulation: 0.09177772998809815
# Iteration no. 34 done. Result of simulation: 0.08379279375076294
# Iteration no. 35 done. Result of simulation: -0.06186579167842865
# Iteration no. 36 done. Result of simulation: -1
# Iteration no. 37 done. Result of simulation: -0.005506962537765503
# Iteration no. 38 done. Result of simulation: 0.07796539068222047
# Iteration no. 39 done. Result of simulation: -0.0006025016307830811
# Iteration no. 40 done. Result of simulation: -0.006524765491485596
# Iteration no. 41 done. Result of simulation: 0.08505882024765016
# Iteration no. 42 done. Result of simulation: 0.022882401943206787
# Iteration no. 43 done. Result of simulation: 0.044270658493041994
# Iteration no. 44 done. Result of simulation: 0.0706398606300354
# Iteration no. 45 done. Result of simulation: -0.02939700484275818
# Iteration no. 46 done. Result of simulation: 0.06494982242584228
# Iteration no. 47 done. Result of simulation: -0.013256072998046875
# Iteration no. 48 done. Result of simulation: -1
# Iteration no. 49 done. Result of simulation: -0.01895822882652283
# Iteration no. 50 done. Result of simulation: 0.003274297714233399
# Iteration no. 51 done. Result of simulation: 0.00641021728515625
# Iteration no. 52 done. Result of simulation: 0.09791454076766969
# Iteration no. 53 done. Result of simulation: 0.021017074584960938
# Iteration no. 54 done. Result of simulation: 0.04995611906051636
# Iteration no. 55 done. Result of simulation: 0.0018425464630126955
# Iteration no. 56 done. Result of simulation: -0.014043539762496948
# Iteration no. 57 done. Result of simulation: 0.021737670898437502
# Iteration no. 58 done. Result of simulation: 1
# Iteration no. 59 done. Result of simulation: -0.0911875955760479
# Iteration no. 60 done. Result of simulation: -0.022923177480697634
# Iteration no. 61 done. Result of simulation: 0.017001080513000488
# Iteration no. 62 done. Result of simulation: -0.05827242434024811
# Iteration no. 63 done. Result of simulation: 0.05581204891204834
# Iteration no. 64 done. Result of simulation: -0.05645961165428162
# Iteration no. 65 done. Result of simulation: 0.08673794269561769
# Iteration no. 66 done. Result of simulation: 0.06290723085403442
# Iteration no. 67 done. Result of simulation: 0.0759164571762085
# Iteration no. 68 done. Result of simulation: 0.0506860613822937
# Iteration no. 69 done. Result of simulation: 0.04343771934509277
# Iteration no. 70 done. Result of simulation: 0.056896317005157473
# Iteration no. 71 done. Result of simulation: 0.024300026893615725
# Iteration no. 72 done. Result of simulation: 0.031836295127868654
# Iteration no. 73 done. Result of simulation: -1
# Iteration no. 74 done. Result of simulation: 0.0645560622215271
# Iteration no. 75 done. Result of simulation: 0.09999358654022217
# Iteration no. 76 done. Result of simulation: -0.013120055198669434
# Iteration no. 77 done. Result of simulation: 0.017184364795684814
# Iteration no. 78 done. Result of simulation: 0.004815185070037842
# Iteration no. 79 done. Result of simulation: 0.03865662813186646
# Iteration no. 80 done. Result of simulation: 0.014723479747772217
# Iteration no. 81 done. Result of simulation: 0.0518802285194397
# Iteration no. 82 done. Result of simulation: -0.06412210166454316
# Iteration no. 83 done. Result of simulation: 0.08230825662612916
# Iteration no. 84 done. Result of simulation: 0.003055262565612793
# Iteration no. 85 done. Result of simulation: -0.09639393873512746
# Iteration no. 86 done. Result of simulation: 0.07410039901733399
# Iteration no. 87 done. Result of simulation: 0.04906740188598633
# Iteration no. 88 done. Result of simulation: -0.048854947090148926
# Iteration no. 89 done. Result of simulation: 0.013335704803466797
# Iteration no. 90 done. Result of simulation: -0.02902398705482483
# Iteration no. 91 done. Result of simulation: 0.04846557378768921
# Iteration no. 92 done. Result of simulation: 0.08752782344818116
# Iteration no. 93 done. Result of simulation: 0.03238316774368286
# Iteration no. 94 done. Result of simulation: 0.07370578050613404
# Iteration no. 95 done. Result of simulation: -0.0056271076202392585
# Iteration no. 96 done. Result of simulation: 0.043813014030456544
# Iteration no. 97 done. Result of simulation: -0.012955671548843384
# Iteration no. 98 done. Result of simulation: 0.027661132812500003
# Iteration no. 99 done. Result of simulation: 0.09844106435775757
# r n . q k b n r
# p p p . p . p p
# . . . p . p . .
# . . . . . . . .
# . . . . . . . .
# . . P . . P . b
# P P . P P . P P
# R N B Q K B . R
# Iteration no. 0 done. Result of simulation: 0.08038550615310669
# Iteration no. 1 done. Result of simulation: 0.024449777603149415
# Iteration no. 2 done. Result of simulation: -0.002666902542114258
# Iteration no. 3 done. Result of simulation: -0.01353864073753357
# Iteration no. 4 done. Result of simulation: -0.02643139958381653
# Iteration no. 5 done. Result of simulation: -1
# Iteration no. 6 done. Result of simulation: 0.005681359767913819
# Iteration no. 7 done. Result of simulation: 0.005681359767913819
# Iteration no. 8 done. Result of simulation: 0.051359724998474125
# Iteration no. 9 done. Result of simulation: -1
# Iteration no. 10 done. Result of simulation: -0.03684983253479004
# Iteration no. 11 done. Result of simulation: -0.09861668981611729
# Iteration no. 12 done. Result of simulation: -0.06755720674991608
# Iteration no. 13 done. Result of simulation: -0.013336539268493652
# Iteration no. 14 done. Result of simulation: 0.010404109954833984
# Iteration no. 15 done. Result of simulation: 0.031391608715057376
# Iteration no. 16 done. Result of simulation: 0.015062403678894044
# Iteration no. 17 done. Result of simulation: -0.055668222904205325
# Iteration no. 18 done. Result of simulation: -0.036777162551879884
# Iteration no. 19 done. Result of simulation: -0.015127933025360108
# Iteration no. 20 done. Result of simulation: 0.027322828769683838
# Iteration no. 21 done. Result of simulation: 0.05685324668884278
# Iteration no. 22 done. Result of simulation: -0.005177223682403565
# Iteration no. 23 done. Result of simulation: 0.06673306226730347
# Iteration no. 24 done. Result of simulation: 0.07491499185562134
# Iteration no. 25 done. Result of simulation: -0.006240898370742798
# Iteration no. 26 done. Result of simulation: 0.043124294281005865
# Iteration no. 27 done. Result of simulation: 0.026582765579223636
# Iteration no. 28 done. Result of simulation: -0.04362415671348572
# Iteration no. 29 done. Result of simulation: -0.00590667724609375
# Iteration no. 30 done. Result of simulation: 0.09956991672515869
# Iteration no. 31 done. Result of simulation: 0.035038995742797854
# Iteration no. 32 done. Result of simulation: -0.019893735647201538
# Iteration no. 33 done. Result of simulation: -0.07226095497608186
# Iteration no. 34 done. Result of simulation: -0.01972845196723938
# Iteration no. 35 done. Result of simulation: -0.03906328082084656
# Iteration no. 36 done. Result of simulation: -0.03199186325073242
# Iteration no. 37 done. Result of simulation: 0.021417105197906496
# Iteration no. 38 done. Result of simulation: -0.02067052721977234
# Iteration no. 39 done. Result of simulation: 0.07130291461944581
# Iteration no. 40 done. Result of simulation: -0.04644669890403748
# Iteration no. 41 done. Result of simulation: 1
# Iteration no. 42 done. Result of simulation: -0.010486418008804323
# Iteration no. 43 done. Result of simulation: -0.047326046228408816
# Iteration no. 44 done. Result of simulation: 0.017443585395812988
# Iteration no. 45 done. Result of simulation: -0.07354053556919098
# Iteration no. 46 done. Result of simulation: -0.03735768795013428
# Iteration no. 47 done. Result of simulation: 0.0812206506729126
# Iteration no. 48 done. Result of simulation: -0.01622922420501709
# Iteration no. 49 done. Result of simulation: 0.0004262089729309082
# Iteration no. 50 done. Result of simulation: 0.06973763704299928
# Iteration no. 51 done. Result of simulation: -0.040962797403335575
# Iteration no. 52 done. Result of simulation: 0.03466116189956665
# Iteration no. 53 done. Result of simulation: 0.045830726623535156
# Iteration no. 54 done. Result of simulation: 0.06925466060638429
# Iteration no. 55 done. Result of simulation: 0.058729708194732666
# Iteration no. 56 done. Result of simulation: -0.009535914659500122
# Iteration no. 57 done. Result of simulation: 0.01840752363204956
# Iteration no. 58 done. Result of simulation: 0.04790219068527222
# Iteration no. 59 done. Result of simulation: 0.012829232215881349
# Iteration no. 60 done. Result of simulation: -0.035147732496261595
# Iteration no. 61 done. Result of simulation: 0.042273795604705816
# Iteration no. 62 done. Result of simulation: -0.09920653020963073
# Iteration no. 63 done. Result of simulation: 0.03462374210357666
# Iteration no. 64 done. Result of simulation: 0.07671959400177003
# Iteration no. 65 done. Result of simulation: -0.023609811067581178
# Iteration no. 66 done. Result of simulation: -1
# Iteration no. 67 done. Result of simulation: 0.011303603649139404
# Iteration no. 68 done. Result of simulation: 0.07124420404434205
# Iteration no. 69 done. Result of simulation: 0.03386971950531006
# Iteration no. 70 done. Result of simulation: 0.09669382572174073
# Iteration no. 71 done. Result of simulation: -0.042234063148498535
# Iteration no. 72 done. Result of simulation: 0.060065507888793945
# Iteration no. 73 done. Result of simulation: 0.03899565935134888
# Iteration no. 74 done. Result of simulation: 0.029459798336029054
# Iteration no. 75 done. Result of simulation: -0.03451078534126282
# Iteration no. 76 done. Result of simulation: -0.0009543240070343018
# Iteration no. 77 done. Result of simulation: -0.005674207210540772
# Iteration no. 78 done. Result of simulation: -0.013435643911361695
# Iteration no. 79 done. Result of simulation: 0.034806132316589355
# Iteration no. 80 done. Result of simulation: 0.005720388889312745
# Iteration no. 81 done. Result of simulation: 0.025103735923767093
# Iteration no. 82 done. Result of simulation: -0.06545053124427795
# Iteration no. 83 done. Result of simulation: -0.04097053408622742
# Iteration no. 84 done. Result of simulation: 0.05646110773086548
# Iteration no. 85 done. Result of simulation: -0.03793361186981201
# Iteration no. 86 done. Result of simulation: -0.02021520733833313
# Iteration no. 87 done. Result of simulation: 0.051275241374969485
# Iteration no. 88 done. Result of simulation: 0.04625935554504395
# Iteration no. 89 done. Result of simulation: -0.03850560784339905
# Iteration no. 90 done. Result of simulation: 0.0358373761177063
# Iteration no. 91 done. Result of simulation: -0.04786816835403443
# Iteration no. 92 done. Result of simulation: 0.013567256927490235
# Iteration no. 93 done. Result of simulation: 0.009332060813903809
# Iteration no. 94 done. Result of simulation: -0.09736712295562029
# Iteration no. 95 done. Result of simulation: -0.05791255831718445
# Iteration no. 96 done. Result of simulation: 0.04431716203689576
# Iteration no. 97 done. Result of simulation: 1
# Iteration no. 98 done. Result of simulation: 0.015397572517395021
# Iteration no. 99 done. Result of simulation: 0.006093120574951172
# r n . q k b n r
# p p p . p . p p
# . . . p . p . .
# . . . . . . . .
# P . . . . . . .
# . . P . . P . b
# . P . P P . P P
# R N B Q K B . R
# Iteration no. 0 done. Result of simulation: -0.023777818679809572
# Iteration no. 1 done. Result of simulation: -0.05530610382556916
# Iteration no. 2 done. Result of simulation: -0.04960328936576844
# Iteration no. 3 done. Result of simulation: -0.02560750246047974
# Iteration no. 4 done. Result of simulation: -0.09998002976790304
# Iteration no. 5 done. Result of simulation: -0.03924518823623657
# Iteration no. 6 done. Result of simulation: 0.09624159336090088
# Iteration no. 7 done. Result of simulation: -0.03571717739105225
# Iteration no. 8 done. Result of simulation: -0.09114338904619218
# Iteration no. 9 done. Result of simulation: -1
# Iteration no. 10 done. Result of simulation: 0.09681898355484009
# Iteration no. 11 done. Result of simulation: -0.03163149356842041
# Iteration no. 12 done. Result of simulation: 0.02868973016738892
# Iteration no. 13 done. Result of simulation: -0.008342087268829346
# Iteration no. 14 done. Result of simulation: 0.04826643466949463
# Iteration no. 15 done. Result of simulation: 0.09757562875747681
# Iteration no. 16 done. Result of simulation: 0.09757562875747681
# Iteration no. 17 done. Result of simulation: 0.09781188964843751
# Iteration no. 18 done. Result of simulation: -0.0091525137424469
# Iteration no. 19 done. Result of simulation: 0.07734336853027345
# Iteration no. 20 done. Result of simulation: 0.002510547637939453
# Iteration no. 21 done. Result of simulation: 0.047806382179260254
# ...
# Iteration no. 30 done. Result of simulation: -0.013835150003433229
# Iteration no. 31 done. Result of simulation: -0.09225095286965371
# Iteration no. 32 done. Result of simulation: -0.03917476534843445
# Iteration no. 33 done. Result of simulation: 0.04248942136764527
# Iteration no. 34 done. Result of simulation: 0.09980908632278443
# Iteration no. 35 done. Result of simulation: 0.09490393400192261
# Iteration no. 36 done. Result of simulation: -0.023508840799331666
# Iteration no. 37 done. Result of simulation: -0.031870436668396
# Iteration no. 38 done. Result of simulation: -0.06363660991191865
# Iteration no. 39 done. Result of simulation: 0.033003377914428714
# Iteration no. 40 done. Result of simulation: -0.07740681767463685
# Iteration no. 41 done. Result of simulation: 0.03008617162704468
# Iteration no. 42 done. Result of simulation: -0.04094210863113404
# Iteration no. 43 done. Result of simulation: -0.024878358840942385
# Iteration no. 44 done. Result of simulation: 0.08255914449691773
# Iteration no. 45 done. Result of simulation: 0.007396328449249268
# Iteration no. 46 done. Result of simulation: -0.031870436668396
# Iteration no. 47 done. Result of simulation: 0.077725088596344
# Iteration no. 48 done. Result of simulation: 0.0562425971031189
# Iteration no. 49 done. Result of simulation: -0.018275642395019533
# Iteration no. 50 done. Result of simulation: -0.0039218544960021974
# Iteration no. 51 done. Result of simulation: 0.09600833654403687
# Iteration no. 52 done. Result of simulation: 0.05789173841476441
# Iteration no. 53 done. Result of simulation: 0.005567598342895508
# Iteration no. 54 done. Result of simulation: 0.027684915065765384
# Iteration no. 55 done. Result of simulation: 0.03353893756866455
# Iteration no. 56 done. Result of simulation: -0.014770227670669557
# Iteration no. 57 done. Result of simulation: 0.0369531512260437
# Iteration no. 58 done. Result of simulation: 0.006872105598449707
# Iteration no. 59 done. Result of simulation: 1
# Iteration no. 60 done. Result of simulation: 0.05831863880157471
# Iteration no. 61 done. Result of simulation: -0.05892189145088196
# Iteration no. 62 done. Result of simulation: -0.08160908967256547
# Iteration no. 63 done. Result of simulation: -0.027553611993789674
# Iteration no. 64 done. Result of simulation: 0.010822737216949464
# Iteration no. 65 done. Result of simulation: 1
# Iteration no. 66 done. Result of simulation: 0.06974434852600098
# Iteration no. 67 done. Result of simulation: -0.018277180194854737
# Iteration no. 68 done. Result of simulation: 0.027039051055908203
# Iteration no. 69 done. Result of simulation: -0.027511054277420045
# Iteration no. 70 done. Result of simulation: -0.07954384386539459
# Iteration no. 71 done. Result of simulation: 0.09633586406707764
# Iteration no. 72 done. Result of simulation: 0.053264522552490236
# Iteration no. 73 done. Result of simulation: -0.008531183004379272
# Iteration no. 74 done. Result of simulation: 0.03408780097961426
# Iteration no. 75 done. Result of simulation: -0.07405535280704499
# Iteration no. 76 done. Result of simulation: 0.053264522552490236
# Iteration no. 77 done. Result of simulation: -0.018245124816894533
# Iteration no. 78 done. Result of simulation: -0.029541981220245362
# Iteration no. 79 done. Result of simulation: -1
# Iteration no. 80 done. Result of simulation: 0.009159910678863526
# Iteration no. 81 done. Result of simulation: 0.08122045993804933
# Iteration no. 82 done. Result of simulation: 0.09996050596237183
# Iteration no. 83 done. Result of simulation: -0.08043695837259293
# Iteration no. 84 done. Result of simulation: 0.021049010753631595
# Iteration no. 85 done. Result of simulation: 0.00697706937789917
# Iteration no. 86 done. Result of simulation: 0.0936774492263794
# Iteration no. 87 done. Result of simulation: -0.043736428022384644
# Iteration no. 88 done. Result of simulation: -1
# Iteration no. 89 done. Result of simulation: 0.01871739625930786
# Iteration no. 90 done. Result of simulation: 0.06617494821548463
# Iteration no. 91 done. Result of simulation: -0.021027374267578128
# Iteration no. 92 done. Result of simulation: -0.01685996651649475
# Iteration no. 93 done. Result of simulation: 0.07161824703216553
# Iteration no. 94 done. Result of simulation: 0.0934682846069336
# Iteration no. 95 done. Result of simulation: -0.04797794818878174
# Iteration no. 96 done. Result of simulation: -0.06696053445339203
# Iteration no. 97 done. Result of simulation: -0.05530931055545807
# Iteration no. 98 done. Result of simulation: 0.09975132942199708
# Iteration no. 99 done. Result of simulation: 0.0934682846069336
# r n . k . b n r
# p p p q . . p p
# . . . p p p . .
# . . . . . . . .
# P . P . . . . .
# . . . . Q P . b
# . P . P P . P P
# R N B . K B . R
# Iteration no. 0 done. Result of simulation: -0.0961826741695404
# Iteration no. 1 done. Result of simulation: -0.0425281822681427
# Iteration no. 2 done. Result of simulation: 0.08560492992401124
# Iteration no. 3 done. Result of simulation: 0.006281852722167969
# Iteration no. 4 done. Result of simulation: 0.07504029273986818
# Iteration no. 5 done. Result of simulation: 0.02100660800933838
# Iteration no. 6 done. Result of simulation: 0.07504029273986818
# Iteration no. 7 done. Result of simulation: 0.09607449769973755
# Iteration no. 8 done. Result of simulation: -0.05854212939739228
# Iteration no. 9 done. Result of simulation: -0.014191555976867677
# Iteration no. 10 done. Result of simulation: 0.011151647567749024
# Iteration no. 11 done. Result of simulation: 0.0777165174484253
# Iteration no. 12 done. Result of simulation: 0.07720878124237061
# Iteration no. 13 done. Result of simulation: 0.09802953004837037
# Iteration no. 14 done. Result of simulation: 0.001569521427154541
# Iteration no. 15 done. Result of simulation: -0.0179452121257782
# Iteration no. 16 done. Result of simulation: -1
# Iteration no. 17 done. Result of simulation: 0.029156744480133057
# Iteration no. 18 done. Result of simulation: 0.06372846364974975
# Iteration no. 19 done. Result of simulation: -0.05339867174625397
# Iteration no. 20 done. Result of simulation: -0.06185153424739838
# Iteration no. 21 done. Result of simulation: -0.009800416231155396
# Iteration no. 22 done. Result of simulation: 0.012355124950408936
# Iteration no. 23 done. Result of simulation: -0.05730081200599671
# Iteration no. 24 done. Result of simulation: 0.09793964624404908
# Iteration no. 25 done. Result of simulation: -0.01207835078239441
# Iteration no. 26 done. Result of simulation: 0.09955066442489624
# Iteration no. 27 done. Result of simulation: 0.022625279426574708
# Iteration no. 28 done. Result of simulation: -0.002312129735946655
# Iteration no. 29 done. Result of simulation: -0.047055196762084965
# Iteration no. 30 done. Result of simulation: 0.017161917686462403
# Iteration no. 31 done. Result of simulation: 0.009907746315002443
# Iteration no. 32 done. Result of simulation: -0.09999078304244904
# Iteration no. 33 done. Result of simulation: -0.00025218129158020023
# Iteration no. 34 done. Result of simulation: 0.009914636611938477
# Iteration no. 35 done. Result of simulation: -0.026869004964828493
# Iteration no. 36 done. Result of simulation: 0.04373025894165039
# Iteration no. 37 done. Result of simulation: 0.07968357801437378
# Iteration no. 38 done. Result of simulation: -0.03968844413757325
# Iteration no. 39 done. Result of simulation: 0.006689238548278809
# Iteration no. 40 done. Result of simulation: 1
# Iteration no. 41 done. Result of simulation: 0.08935550451278687
# Iteration no. 42 done. Result of simulation: 0.0842214584350586
# Iteration no. 43 done. Result of simulation: -0.06984880268573761
# Iteration no. 44 done. Result of simulation: 0.006689238548278809
# Iteration no. 45 done. Result of simulation: -0.09998898876219756
# Iteration no. 46 done. Result of simulation: 0.03353360891342163
# Iteration no. 47 done. Result of simulation: 0.015012085437774658
# Iteration no. 48 done. Result of simulation: -0.0834420070052147
# Iteration no. 49 done. Result of simulation: -0.017193466424942017
# Iteration no. 50 done. Result of simulation: 0.09969944953918458
# Iteration no. 51 done. Result of simulation: 0.011208462715148927
# Iteration no. 52 done. Result of simulation: -0.0498197078704834
# Iteration no. 53 done. Result of simulation: 0.08765367269515992
# Iteration no. 54 done. Result of simulation: 0.06619361639022828
# Iteration no. 55 done. Result of simulation: 0.006689238548278809
# Iteration no. 56 done. Result of simulation: 0.05559160709381104
# Iteration no. 57 done. Result of simulation: 0.09818384647369385
# Iteration no. 58 done. Result of simulation: 0.027868795394897464
# Iteration no. 59 done. Result of simulation: 0.09529050588607789
# Iteration no. 60 done. Result of simulation: -0.005213791131973267
# Iteration no. 61 done. Result of simulation: -0.006507384777069092
# Iteration no. 62 done. Result of simulation: -0.09976036187727005
# Iteration no. 63 done. Result of simulation: 0.0697129487991333
# Iteration no. 64 done. Result of simulation: -0.024670064449310303
# Iteration no. 65 done. Result of simulation: -0.04437826275825501
# Iteration no. 66 done. Result of simulation: 0.024301016330718996
# Iteration no. 67 done. Result of simulation: 0.09317682981491089
# Iteration no. 68 done. Result of simulation: 0.0998159170150757
# Iteration no. 69 done. Result of simulation: -1
# Iteration no. 70 done. Result of simulation: 0.09787555932998658
# Iteration no. 71 done. Result of simulation: 0.09864312410354614
# Iteration no. 72 done. Result of simulation: 0.017161917686462403
# Iteration no. 73 done. Result of simulation: 0.048954176902771
# Iteration no. 74 done. Result of simulation: 0.04494402408599854
# Iteration no. 75 done. Result of simulation: 0.003410470485687256
# Iteration no. 76 done. Result of simulation: 0.09529050588607789
# Iteration no. 77 done. Result of simulation: -0.043838882446289064
# Iteration no. 78 done. Result of simulation: -0.0388343095779419
# Iteration no. 79 done. Result of simulation: 0.02755473852157593
# Iteration no. 80 done. Result of simulation: 0.011159741878509523
# Iteration no. 81 done. Result of simulation: 0.004589831829071045
# Iteration no. 82 done. Result of simulation: 0.07736750841140748
# Iteration no. 83 done. Result of simulation: 0.0550201416015625
# Iteration no. 84 done. Result of simulation: -0.05769882202148438
# Iteration no. 85 done. Result of simulation: 0.021690285205841067
# Iteration no. 86 done. Result of simulation: -0.05575186312198639
# Iteration no. 87 done. Result of simulation: 0.05891485214233399
# Iteration no. 88 done. Result of simulation: 0.02801613807678223
# Iteration no. 89 done. Result of simulation: 0.058190262317657476
# Iteration no. 90 done. Result of simulation: 0.004402816295623779
# Iteration no. 91 done. Result of simulation: 0.024019849300384522
# Iteration no. 92 done. Result of simulation: 0.012387144565582276
# Iteration no. 93 done. Result of simulation: -0.016042387485504152
# Iteration no. 94 done. Result of simulation: 0.0006032943725585938
# Iteration no. 95 done. Result of simulation: 0.02721648216247559
# Iteration no. 96 done. Result of simulation: -0.028567582368850708
# Iteration no. 97 done. Result of simulation: 0.017048168182373046
# Iteration no. 98 done. Result of simulation: -0.08948864713311196
# Iteration no. 99 done. Result of simulation: -0.0073458731174469
# r n . k . b n r
# p p p q . . p p
# . . . p p p . .
# . . . . . . . .
# P . P . . . . .
# . . . . Q P . .
# . P . P P . b P
# R N B . K B . R
# Iteration no. 0 done. Result of simulation: 0.0561102032661438
# Iteration no. 1 done. Result of simulation: 0.09955296516418458
# Iteration no. 2 done. Result of simulation: 0.0878919243812561
# Iteration no. 3 done. Result of simulation: -0.08911651745438576
# Iteration no. 4 done. Result of simulation: 0.044625508785247806
# Iteration no. 5 done. Result of simulation: 0.02694652080535889
# Iteration no. 6 done. Result of simulation: -1
# Iteration no. 7 done. Result of simulation: -0.09839964658021927
# Iteration no. 8 done. Result of simulation: -0.023237580060958864
# Iteration no. 9 done. Result of simulation: -0.09471180550754071
# Iteration no. 10 done. Result of simulation: 0.053289592266082764
# Iteration no. 11 done. Result of simulation: 0.05050650835037232
# Iteration no. 12 done. Result of simulation: 0.04219406843185425
# Iteration no. 13 done. Result of simulation: 0.04011702537536621
# Iteration no. 14 done. Result of simulation: -0.000978386402130127
# Iteration no. 15 done. Result of simulation: 0.04967765808105469
# Iteration no. 16 done. Result of simulation: 0.08588517904281617
# Iteration no. 17 done. Result of simulation: 0.07871049642562866
# Iteration no. 18 done. Result of simulation: 0.07102586030960083
# Iteration no. 19 done. Result of simulation: -0.047864031791687016
# Iteration no. 20 done. Result of simulation: -0.06450014114379883
# Iteration no. 21 done. Result of simulation: 0.08178198337554932
# Iteration no. 22 done. Result of simulation: -0.08098899871110916
# Iteration no. 23 done. Result of simulation: -0.09872789354994893
# Iteration no. 24 done. Result of simulation: 0.010860264301300049
# Iteration no. 25 done. Result of simulation: 0.04863996505737305
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-abf5940e233c> in <cell line: 20>()
#      18     print("Game over")
#      19
# ---> 20 play()
#
# <ipython-input-27-abf5940e233c> in play()
#       9         if board.turn == chess.WHITE:
#      10             #move = input("Enter move: ")
# ---> 11             node = run_mcts(model, node, num_iterations=100, simulation_depth=100, epsilon=1.0)
#      12             move = str(node.parent_action)
#      13             board.push_san(move)
#
# <ipython-input-26-955e751b2c4a> in run_mcts(model, initial_node, num_iterations, simulation_depth, epsilon)
#     254         best_child = selection(node)
#     255         node = best_child
# --> 256         result = simulate(node, model, max_iterations=simulation_depth, epsilon=epsilon)
#     257         #rollback from selected node using the result
#     258         #print(result)
#
# <ipython-input-26-955e751b2c4a> in simulate(initial_node, model, max_iterations, epsilon, display_board, seed)
#     157     while (True):
#     158         iter_index += 1
# --> 159         find_next_best_legal_position(model, board, epsilon)
#     160         #next_node = Node(next_position, current_node)
#     161         #current_node.children.append(next_node)
#
# <ipython-input-26-955e751b2c4a> in find_next_best_legal_position(model, board, epsilon)
#     100         #print(board.fen())
#     101         #print(get_eval(model, position))
# --> 102         current_move_eval = get_eval(model, position)
#     103         #print(current_move_eval)
#     104         #print(move)
#
# <ipython-input-26-955e751b2c4a> in get_eval(model, position)
#      80     # position is a FEN string
#      81     model.eval()
# ---> 82     position_vec = fen_to_vector(position)
#      83     position_vec = (torch.tensor(position_vec)).float().to(DEVICE)
#      84     pred = model(position_vec).item()
#
# <ipython-input-4-7d6981587450> in fen_to_vector(fen_string)
#      24         A 12 x 8 x 8 numpy array representing the bitboard vector.
#      25     """
# ---> 26     board = chess.Board(fen_string)
#      27
#      28     black, white = board.occupied_co
#
# /usr/local/lib/python3.10/dist-packages/chess/__init__.py in __init__(self, fen, chess960)
#    1596             self.reset()
#    1597         else:
# -> 1598             self.set_fen(fen)
#    1599
#    1600     @property
#
# /usr/local/lib/python3.10/dist-packages/chess/__init__.py in set_fen(self, fen)
#    2534
#    2535         # Validate the board part and set it.
# -> 2536         self._set_board_fen(board_part)
#    2537
#    2538         # Apply.
#
# /usr/local/lib/python3.10/dist-packages/chess/__init__.py in _set_board_fen(self, fen)
#    1026
#    1027             for c in row:
# -> 1028                 if c in ["1", "2", "3", "4", "5", "6", "7", "8"]:
#    1029                     if previous_was_digit:
#    1030                         raise ValueError(f"two subsequent digits in position part of fen: {fen!r}")
#
# KeyboardInterrupt:
